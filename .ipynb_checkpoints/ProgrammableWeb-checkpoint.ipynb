# %%
# Question: web scrape the API lists on this page, and export your result into a CSV file.

# https://www.programmableweb.com/category/all/apis
'''
Your Python code should scrape the following details from each table row:

• API Name

• API (absolute) URL

• API Category

• API Description
'''
# Your Python code should crawl to all the available "next" pages. Your final result should be approx. 20,400 rows
# Out:
# '\nYour Python code should scrape the following details from each table row:\n\n• API Name\n\n• API (absolute) URL\n\n• API Category\n\n• API Description\n'

# %%
# import the required packages
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.programmableweb.com/category/all/apis"  # url to be scraped.
url_2 = "https://www.programmableweb.com/"
master_list = []

try:
    while True:

        response = requests.get(url)
        print(response.status_code)
        soup = BeautifulSoup(response.text) # Pass the requested page in to a bs4 object

        table = soup.find('table', {'class':'views-table'})
        table_rows = table.tbody.find_all('tr')
        for row in table_rows:
            API_NAME = row.find('td', {'class':'views-field-pw-version-title'}).text.strip()
            API_URL = url_2 + row.find('td', {'class':'views-field-pw-version-title'}).a['href']
            API_CATEGORY = row.find('td', {'class':'views-field-field-article-primary-category'}).text.strip()
            API_DESCRIPTION = row.find('td', {'class':'views-field-field-api-description'}).text.strip()
            API_FOLLOWER = row.find('td', {'class':'views-field-flag-follow-api-count'}).text.strip()
            API_DICT = {}
            API_DICT['API_NAME'] = API_NAME
            API_DICT['API_URL'] = API_URL
            API_DICT['API_CATEGORY'] = API_CATEGORY
            API_DICT['API_DESCRIPTION'] = API_DESCRIPTION
            API_DICT['API_FOLLOWER'] = API_FOLLOWER
            master_list.append(API_DICT)
        NEXT_PAGE_URL = soup.find('a', {'title':'Go to next page'})['href']
        if NEXT_PAGE_URL:
            url = "https://www.programmableweb.com" + NEXT_PAGE_URL
            print(url)
    #     elif len(count) == 5:
    #         break
        else:
            break
except:
    print('failed!')
# Out:
# failed!

# %%
df = pd.DataFrame(master_list)

# %%
len(master_list)
# Out:
# 25

# %%
df
# Out:
#                     API_NAME  \
# 0          Authorize.Net API
# 1    Aonaware Dictionary API
# 2                RapLeaf API
# 3        Alexa Top Sites API
# 4               Nestoria API
# 5     Microsoft MapPoint API
# 6               43Things API
# 7                   Ning API
# 8            LiveJournal API
# 9           Walmart Open API
# 10                 Giphy API
# 11                Zapier API
# 12         BitStamp HTTP API
# 13                 500px API
# 14                 uShip API
# 15       Bing Translator API
# 16   Instagram Real-time API
# 17                PicPlz API
# 18            Amazon SES API
# 19  Google URL Shortener API
# 20                 Yipit API
# 21                KooKoo API
# 22           JournalTOCs API
# 23                Yellow API
# 24                Pusher API
#
#                                               API_URL   API_CATEGORY  \
# 0   https://www.programmableweb.com//api/authorizenet       Payments
# 1   https://www.programmableweb.com//api/aonaware-...      Reference
# 2        https://www.programmableweb.com//api/rapleaf          Email
# 3   https://www.programmableweb.com//api/alexa-top...            SEO
# 4       https://www.programmableweb.com//api/nestoria    Real Estate
# 5   https://www.programmableweb.com//api/microsoft...        Mapping
# 6       https://www.programmableweb.com//api/43things          Goals
# 7           https://www.programmableweb.com//api/ning         Social
# 8    https://www.programmableweb.com//api/livejournal       Blogging
# 9   https://www.programmableweb.com//api/walmart-open      eCommerce
# 10         https://www.programmableweb.com//api/giphy         Search
# 11        https://www.programmableweb.com//api/zapier          Tools
# 12  https://www.programmableweb.com//api/bitstamp-...      Financial
# 13         https://www.programmableweb.com//api/500px         Photos
# 14         https://www.programmableweb.com//api/uship       Shipping
# 15  https://www.programmableweb.com//api/bing-tran...          Tools
# 16  https://www.programmableweb.com//api/instagram...         Photos
# 17        https://www.programmableweb.com//api/picplz         Photos
# 18    https://www.programmableweb.com//api/amazon-ses          Email
# 19  https://www.programmableweb.com//api/google-ur...  URL Shortener
# 20         https://www.programmableweb.com//api/yipit      eCommerce
# 21        https://www.programmableweb.com//api/kookoo      Telephony
# 22   https://www.programmableweb.com//api/journaltocs         Search
# 23        https://www.programmableweb.com//api/yellow         Search
# 24        https://www.programmableweb.com//api/pusher          Tools
#
#                                       API_DESCRIPTION API_FOLLOWER
# 0   Authorize.Net provides IP based payment gatewa...          106
# 1                                                               87
# 2   The personalization API provides a simple inte...           43
# 3   From their site: The Alexa Top Sites web servi...           87
# 4   Nestoria is a vertical search engine for prope...           38
# 5   Note that this is a commercial, fee-based serv...           25
# 6   43 Things is a social networking web site that...           19
# 7   Ning is a platform for creating social network...           68
# 8   The LiveJournal API allows developers to edit ...           42
# 9   The Walmart Open APIs provide developers with ...           95
# 10  Giphy is an animated search engine for discove...          154
# 11  Zapier is an application that integrates appli...           67
# 12  BitStamp is an online exchange for bitcoins. O...           40
# 13  This API is no longer publicly available, plea...           66
# 14  uShip is an online shipping marketplace that c...           44
# 15  The Microsoft Translator services can be used ...           12
# 16  Instagram Real-time API provides access to Ins...          153
# 17  Photo sharing mobile application picplz has a ...           14
# 18  Amazon Simple Email Service, or SES, provides ...           27
# 19                                                              56
# 20  Per provider, this API is now closed and API k...           38
# 21  KooKoo acts as an interface between your appli...           32
# 22  Developers can use the JournalTOCs API to embe...            5
# 23  YellowAPIâ„¢ is an application programming int...           27
# 24  Pusher is a simple hosted API for quickly, eas...          132

# %%
master_list
# Out:
# [{'API_NAME': 'Authorize.Net API',
#   'API_URL': 'https://www.programmableweb.com//api/authorizenet',
#   'API_CATEGORY': 'Payments',
#   'API_DESCRIPTION': 'Authorize.Net provides IP based payment gateway services. The Authorize.Net API enables developers to integrate digital payments into applications. It is optimized for mobile, provides PCI compliance...',
#   'API_FOLLOWER': '106'},
#  {'API_NAME': 'Aonaware Dictionary API',
#   'API_URL': 'https://www.programmableweb.com//api/aonaware-dictionary',
#   'API_CATEGORY': 'Reference',
#   'API_DESCRIPTION': '',
#   'API_FOLLOWER': '87'},
#  {'API_NAME': 'RapLeaf API',
#   'API_URL': 'https://www.programmableweb.com//api/rapleaf',
#   'API_CATEGORY': 'Email',
#   'API_DESCRIPTION': 'The personalization API provides a simple interface to rich data about consumers. Developers use the data provided by the API to create more personalized experiences for consumers.\nQuery with an...',
#   'API_FOLLOWER': '43'},
#  {'API_NAME': 'Alexa Top Sites API',
#   'API_URL': 'https://www.programmableweb.com//api/alexa-top-sites',
#   'API_CATEGORY': 'SEO',
#   'API_DESCRIPTION': 'From their site: The Alexa Top Sites web service provides access to lists of web sites ordered by Alexa Traffic Rank. Using the web service developers can understand traffic rankings from the largest...',
#   'API_FOLLOWER': '87'},
#  {'API_NAME': 'Nestoria API',
#   'API_URL': 'https://www.programmableweb.com//api/nestoria',
#   'API_CATEGORY': 'Real Estate',
#   'API_DESCRIPTION': 'Nestoria is a vertical search engine for property in the UK and Spain. The site offers an API to their database of geocoded properties.',
#   'API_FOLLOWER': '38'},
#  {'API_NAME': 'Microsoft MapPoint API',
#   'API_URL': 'https://www.programmableweb.com//api/microsoft-mappoint',
#   'API_CATEGORY': 'Mapping',
#   'API_DESCRIPTION': 'Note that this is a commercial, fee-based service but that 45 trial accounts are available.',
#   'API_FOLLOWER': '25'},
#  {'API_NAME': '43Things API',
#   'API_URL': 'https://www.programmableweb.com//api/43things',
#   'API_CATEGORY': 'Goals',
#   'API_DESCRIPTION': '43 Things is a social networking web site that is built on the principles of tagging, rather than links. Users create accounts and then list a number of goals or hopes; these goals are connected to...',
#   'API_FOLLOWER': '19'},
#  {'API_NAME': 'Ning API',
#   'API_URL': 'https://www.programmableweb.com//api/ning',
#   'API_CATEGORY': 'Social',
#   'API_DESCRIPTION': 'Ning is a platform for creating social networks. The Ning REST API integrates with any Ning Pro account to import, export, and share data from apps running on Ning across the web or onto your desktop...',
#   'API_FOLLOWER': '68'},
#  {'API_NAME': 'LiveJournal API',
#   'API_URL': 'https://www.programmableweb.com//api/livejournal',
#   'API_CATEGORY': 'Blogging',
#   'API_DESCRIPTION': "The LiveJournal API allows developers to edit a journal entry, edit friend groups, retrieve a list of a user's friends, download parts of a user's journal, and perform other interactions with the...",
#   'API_FOLLOWER': '42'},
#  {'API_NAME': 'Walmart Open API',
#   'API_URL': 'https://www.programmableweb.com//api/walmart-open',
#   'API_CATEGORY': 'eCommerce',
#   'API_DESCRIPTION': "The Walmart Open APIs provide developers with access to Walmart.com's product catalogue information and enable affiliates to earn money through customer referrals. The Data Feed and Special Feeds...",
#   'API_FOLLOWER': '95'},
#  {'API_NAME': 'Giphy API',
#   'API_URL': 'https://www.programmableweb.com//api/giphy',
#   'API_CATEGORY': 'Search',
#   'API_DESCRIPTION': 'Giphy is an animated search engine for discovering and sharing GIF images. Giphy exposes its search capabilities through a RESTlike API. The API is comprised of nine JSON endpoints, allowing...',
#   'API_FOLLOWER': '154'},
#  {'API_NAME': 'Zapier API',
#   'API_URL': 'https://www.programmableweb.com//api/zapier',
#   'API_CATEGORY': 'Tools',
#   'API_DESCRIPTION': 'Zapier is an application that integrates applications together. Users can choose triggers that automatically push data and content from one application to another.\nWith Zapier, developers and users...',
#   'API_FOLLOWER': '67'},
#  {'API_NAME': 'BitStamp HTTP API',
#   'API_URL': 'https://www.programmableweb.com//api/bitstamp-http',
#   'API_CATEGORY': 'Financial',
#   'API_DESCRIPTION': 'BitStamp is an online exchange for bitcoins. Online consumers and traders can use it as a global marketplace to buy and sell BitCoins. Users make cash deposits to buy bitcoins from other users. They...',
#   'API_FOLLOWER': '40'},
#  {'API_NAME': '500px API',
#   'API_URL': 'https://www.programmableweb.com//api/500px',
#   'API_CATEGORY': 'Photos',
#   'API_DESCRIPTION': 'This API is no longer publicly available, please email sales@500px.com to discuss further usage of the API.\n500px is an online community for photographers and fans of photography. Photographers...',
#   'API_FOLLOWER': '66'},
#  {'API_NAME': 'uShip API',
#   'API_URL': 'https://www.programmableweb.com//api/uship',
#   'API_CATEGORY': 'Shipping',
#   'API_DESCRIPTION': "uShip is an online shipping marketplace that connects people with customer-reviewed transport companies. Transporters use uShip to place competing bids to win a customer's business and meet their...",
#   'API_FOLLOWER': '44'},
#  {'API_NAME': 'Bing Translator API',
#   'API_URL': 'https://www.programmableweb.com//api/bing-translator',
#   'API_CATEGORY': 'Tools',
#   'API_DESCRIPTION': 'The Microsoft Translator services can be used in web or client applications to perform language translation operations. The API can be used with either REST, SOAP or JavaScript protocol and responses...',
#   'API_FOLLOWER': '12'},
#  {'API_NAME': 'Instagram Real-time API',
#   'API_URL': 'https://www.programmableweb.com//api/instagram-real-time',
#   'API_CATEGORY': 'Photos',
#   'API_DESCRIPTION': "Instagram Real-time API provides access to Instagram photos as they're added. Subscribe to users, tags, locations or geographies and receive notice when there are new photos. The real-time API uses...",
#   'API_FOLLOWER': '153'},
#  {'API_NAME': 'PicPlz API',
#   'API_URL': 'https://www.programmableweb.com//api/picplz',
#   'API_CATEGORY': 'Photos',
#   'API_DESCRIPTION': 'Photo sharing mobile application picplz has a new API that has entered beta. The service provides read/write access to the picplz platform for sharing and editing photos. Developers can upload photos...',
#   'API_FOLLOWER': '14'},
#  {'API_NAME': 'Amazon SES API',
#   'API_URL': 'https://www.programmableweb.com//api/amazon-ses',
#   'API_CATEGORY': 'Email',
#   'API_DESCRIPTION': 'Amazon Simple Email Service, or SES, provides cloud-based email as a service. Amazon SES simplifies sending emails from applications being hosted on services such as Amazon EC2. Because email...',
#   'API_FOLLOWER': '27'},
#  {'API_NAME': 'Google URL Shortener API',
#   'API_URL': 'https://www.programmableweb.com//api/google-url-shortener',
#   'API_CATEGORY': 'URL Shortener',
#   'API_DESCRIPTION': '',
#   'API_FOLLOWER': '56'},
#  {'API_NAME': 'Yipit API',
#   'API_URL': 'https://www.programmableweb.com//api/yipit',
#   'API_CATEGORY': 'eCommerce',
#   'API_DESCRIPTION': 'Per provider, this API is now closed and API keys are no longer being distributed. Users of the API before it was closed continue to have access to the API but that is not being fully supported...',
#   'API_FOLLOWER': '38'},
#  {'API_NAME': 'KooKoo API',
#   'API_URL': 'https://www.programmableweb.com//api/kookoo',
#   'API_CATEGORY': 'Telephony',
#   'API_DESCRIPTION': 'KooKoo acts as an interface between your applications and telephony applications, allowing users to setup an extra delivery channel for their web applications. It can perform telephony applications...',
#   'API_FOLLOWER': '32'},
#  {'API_NAME': 'JournalTOCs API',
#   'API_URL': 'https://www.programmableweb.com//api/journaltocs',
#   'API_CATEGORY': 'Search',
#   'API_DESCRIPTION': 'Developers can use the JournalTOCs API to embed the search functionality within their web applications to make the most of the journal TOC RSS feeds metadata. Anyone with access to RSS Readers can...',
#   'API_FOLLOWER': '5'},
#  {'API_NAME': 'Yellow API',
#   'API_URL': 'https://www.programmableweb.com//api/yellow',
#   'API_CATEGORY': 'Search',
#   'API_DESCRIPTION': 'YellowAPIâ„¢ is an application programming interface that allows you to stream top Canadian local search content into your applications. Using the database of over 1.5 million business listings and...',
#   'API_FOLLOWER': '27'},
#  {'API_NAME': 'Pusher API',
#   'API_URL': 'https://www.programmableweb.com//api/pusher',
#   'API_CATEGORY': 'Tools',
#   'API_DESCRIPTION': 'Pusher is a simple hosted API for quickly, easily and securely adding realtime bi-directional functionality via WebSockets to web and mobile apps, or any other Internet connected device.\nWe offer a...',
#   'API_FOLLOWER': '132'}]

# %%
url = "https://www.programmableweb.com/category/all/apis"
response = requests.get(url)
soup = BeautifulSoup(response.text)
NEXT_PAGE = soup.find( 'ul', {'class':'pagination'})
NEXT_PAG_BTN = NEXT_PAGE.find('li', {'class':'pager-last'})
if NEXT_PAG_BTN.find('a', {'title':'Go to next page'})['href']:
    print('available')
else:
    print('not available')

# %%
NEXT_PAGE = soup.find( 'ul', {'class':'pagination'})
NEXT_PAG_BTN = NEXT_PAGE.find('li', {'class':'pager-last'})
NEXT_PAGE_URL = NEXT_PAG_BTN.find('a', {'title':'Go to next page'})['href']

# %%
NEXT_PAGE_URL

# %%
soup.find('a', {'title':'Go to next page'})['href']

# %%
find('a', {'class':'Go to page'})
